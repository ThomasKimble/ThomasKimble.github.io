# %% [markdown]
# # 3 Agents

# %%
import scipy.io
import pandas as pd
import plotly.graph_objs as go


position = scipy.io.loadmat('traj3.mat').get("pos_k_i")

agent1_x = np.array(pd.DataFrame(position[0])[0])
agent1_y = np.array(pd.DataFrame(position[1])[0])
agent1_z = np.array(pd.DataFrame(position[2])[0])

agent2_x = np.array(pd.DataFrame(position[0])[1])
agent2_y = np.array(pd.DataFrame(position[1])[1])
agent2_z = np.array(pd.DataFrame(position[2])[1])

agent3_x = np.array(pd.DataFrame(position[0])[2])
agent3_y = np.array(pd.DataFrame(position[1])[2])
agent3_z = np.array(pd.DataFrame(position[2])[2])

agent1_index = []
agent2_index = []
agent3_index = []
time = []
t = 0
for i in range(len(agent1_x)):
    agent1_index.append("Agent 1")
    agent2_index.append("Agent 2")
    agent3_index.append("Agent 3")
    time.append(t)
    t = t+0.2
    
    
agent1_df = pd.DataFrame(list(zip(time,agent1_index,agent1_x,agent1_y,agent1_z)), columns=['Time','Agent','X','Y','Z'])

agent2_df = pd.DataFrame(list(zip(time,agent2_index,agent2_x,agent2_y,agent2_z)), columns=['Time','Agent','X','Y','Z'])

agent3_df = pd.DataFrame(list(zip(time,agent3_index,agent3_x,agent3_y,agent3_z)), columns=['Time','Agent','X','Y','Z'])

pos_df = agent1_df.append(agent2_df)
pos_df = pos_df.append(agent3_df)

pos_df
# Out:
#     Time    Agent         X         Y         Z
# 0    0.0  Agent 1  2.500000  2.408089  1.026858
# 1    0.2  Agent 1  2.500061  2.408150  1.026980
# 2    0.4  Agent 1  2.497817  2.405906  1.027084
# 3    0.6  Agent 1  2.486198  2.394287  1.027368
# 4    0.8  Agent 1  2.455597  2.363686  1.027959
# ..   ...      ...       ...       ...       ...
# 46   9.2  Agent 3 -2.511284  0.703810  0.883243
# 47   9.4  Agent 3 -2.512435  0.704032  0.888064
# 48   9.6  Agent 3 -2.512897  0.704218  0.892118
# 49   9.8  Agent 3 -2.512809  0.704374  0.895500
# 50  10.0  Agent 3 -2.512288  0.704503  0.898296
#
# [153 rows x 5 columns]

# %%
c = ["#fdb73e", "#00C1CC", '#008CFF', '#8BEB98', '#CF69FF', '#FF7396']

last = len(agent1_x)-1

start1 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 1'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 1'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 1'].Z[0]],
    mode='markers',
    name='Start 1',
    marker=dict(symbol="circle",color=c[0],size=5),
    hovertemplate='Agent 1 start<extra></extra>'
)

end1 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 1'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 1'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 1'].Z[last]],
    mode='markers',
    name='End 1',
    marker=dict(symbol="square",color=c[0],size=5),
    hovertemplate='Agent 1 end<extra></extra>'
)

traj1 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 1'].X,
    y=pos_df[pos_df.Agent=='Agent 1'].Y,
    z=pos_df[pos_df.Agent=='Agent 1'].Z,
    mode='lines',
    name='Trajectory 1',
    line=dict(width=5, color=c[0]),
    hovertemplate='Agent 1 trajectory<extra></extra>'
)

start2 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 2'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 2'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 2'].Z[0]],
    mode='markers',
    name='Start 2',
    marker=dict(symbol="circle",color=c[1],size=5),
    hovertemplate='Agent 2 start<extra></extra>'
)

end2 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 2'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 2'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 2'].Z[last]],
    mode='markers',
    name='End 2',
    marker=dict(symbol="square",color=c[1],size=5),
    hovertemplate='Agent 2 end<extra></extra>'
)

traj2 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 2'].X,
    y=pos_df[pos_df.Agent=='Agent 2'].Y,
    z=pos_df[pos_df.Agent=='Agent 2'].Z,
    mode='lines',
    name='Trajectory 2',
    line=dict(width=5, color=c[1]),
    hovertemplate='Agent 2 end<extra></extra>'
)

start3 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 3'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 3'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 3'].Z[0]],
    mode='markers',
    name='Start 3',
    marker=dict(symbol="circle",color=c[2],size=5),
    hovertemplate='Agent 3 start<extra></extra>'
)

end3 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 3'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 3'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 3'].Z[last]],
    mode='markers',
    name='End 3',
    marker=dict(symbol="square",color=c[2],size=5),
    hovertemplate='Agent 3 end<extra></extra>'
)

traj3 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 3'].X,
    y=pos_df[pos_df.Agent=='Agent 3'].Y,
    z=pos_df[pos_df.Agent=='Agent 3'].Z,
    mode='lines',
    name='Trajectory 3',
    line=dict(width=5, color=c[2]),
    hovertemplate='Agent 3 trajectory<extra></extra>'
)

start = go.Scatter3d(
    x=[10],
    y=[10],
    z=[10],
    mode='markers',
    name='Start',
    marker=dict(symbol="circle",color="#fdb73e",size=5)
)

end = go.Scatter3d(
    x=[10],
    y=[10],
    z=[10],
    mode='markers',
    name='End',
    marker=dict(symbol="square",color="#fdb73e",size=5)
)

traj = go.Scatter3d(
    x=[10],
    y=[10],
    z=[10],
    mode='lines',
    name='Trajectory',
    line=dict(width=5, color="#fdb73e")
)

start_zone = go.Mesh3d(
        x=[-2.5, -2.5, -2.5, -2.5],
        y=[-3, -3, 3, 3],
        z=[1.2, 0.8, 1.2, 0.8],

        i=[0, 0, 0, 1],
        j=[1, 2, 3, 2],
        k=[2, 3, 1, 3],
        opacity=0.1,
        color='#fdb73e',
        flatshading = True,
        hovertemplate='Even Agent<br>Start Zone<extra></extra>'
    )

end_zone = go.Mesh3d(
        x=[2.5, 2.5, 2.5, 2.5],
        y=[-3, -3, 3, 3],
        z=[1.2, 0.8, 1.2, 0.8],

        i=[0, 0, 0, 1],
        j=[1, 2, 3, 2],
        k=[2, 3, 1, 3],
        opacity=0.1,
        color='#fdb73e',
        flatshading = True,
        hovertemplate='Odd Agent<br>Start Zone<extra></extra>'
    )

fig = go.Figure(data=[start1, end1, traj1, 
                      start2, end2, traj2, 
                      start3, end3, traj3,
                      start, end, traj,
                      start_zone, end_zone])

fig.update_layout({
    'paper_bgcolor': 'rgba(0, 0, 0, 0)',
    'scene_xaxis_backgroundcolor': 'rgba(47, 47, 65, 0.3)',
    'scene_yaxis_backgroundcolor': 'rgba(47, 47, 65, 0.3)',
    'scene_zaxis_backgroundcolor': 'rgba(47, 47, 65, 0.3)',
    'scene_xaxis_linecolor': 'rgba(0, 0, 0, 0)',
    'scene_yaxis_linecolor': 'rgba(0, 0, 0, 0)',
    'scene_zaxis_linecolor': 'rgba(0, 0, 0, 0)',
    'scene_xaxis_gridcolor': 'rgba(0, 0, 0, 0)',
    'scene_yaxis_gridcolor': 'rgba(0, 0, 0, 0)',
    'scene_zaxis_gridcolor': 'rgba(0, 0, 0, 0)',
    
})

fig.update_layout(
    font_color="#fdb73e",
    title={
        'text': "Collision Free Trajecotries with N=3 Agents",
        'y':0.89,
        'x':0.50,
        'font_size': 20}
)

fig.update_layout(
    scene = dict(
        xaxis = dict(range=[-3.5,3.5],),
        yaxis = dict(range=[-3.5,3.5],),
        zaxis = dict(nticks=3, range=[0,2.5],),)
)


fig.update_layout(
    scene_camera = dict(
        up = dict(x=0, y=0, z=1),
        center = dict(x=0, y=0, z=-0.2),
        eye = dict(x=1.2, y=0.5, z=0.5))
)

labels_to_show_in_legend = ["Start","End","Trajectory","Zone"]

for trace in fig['data']: 
    if (not trace['name'] in labels_to_show_in_legend):
        trace['showlegend'] = False

        
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.9,
    xanchor="left",
    x=0.9
))

fig.update_layout(scene_aspectratio=dict(x=1, y=1, z=0.4))

fig.write_html("traj3.html")

fig.show()
# Out:
# <div>                            <div id="75c0953a-48e9-4f82-aaef-75a1e1a15efb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75c0953a-48e9-4f82-aaef-75a1e1a15efb")) {                    Plotly.newPlot(                        "75c0953a-48e9-4f82-aaef-75a1e1a15efb",                        [{"hovertemplate": "Agent 1 start<extra></extra>", "marker": {"color": "#fdb73e", "size": 5, "symbol": "circle"}, "mode": "markers", "name": "Start 1", "showlegend": false, "type": "scatter3d", "x": [2.5], "y": [2.40808873820707], "z": [1.0268577447591982]}, {"hovertemplate": "Agent 1 end<extra></extra>", "marker": {"color": "#fdb73e", "size": 5, "symbol": "square"}, "mode": "markers", "name": "End 1", "showlegend": false, "type": "scatter3d", "x": [-2.51228685384
# ...

# %% [markdown]
# # 6 Agents

# %%
position = scipy.io.loadmat('traj6.mat').get("pos_k_i")

agent1_x = np.array(pd.DataFrame(position[0])[0])
agent1_y = np.array(pd.DataFrame(position[1])[0])
agent1_z = np.array(pd.DataFrame(position[2])[0])

agent2_x = np.array(pd.DataFrame(position[0])[1])
agent2_y = np.array(pd.DataFrame(position[1])[1])
agent2_z = np.array(pd.DataFrame(position[2])[1])

agent3_x = np.array(pd.DataFrame(position[0])[2])
agent3_y = np.array(pd.DataFrame(position[1])[2])
agent3_z = np.array(pd.DataFrame(position[2])[2])

agent4_x = np.array(pd.DataFrame(position[0])[3])
agent4_y = np.array(pd.DataFrame(position[1])[3])
agent4_z = np.array(pd.DataFrame(position[2])[3])

agent5_x = np.array(pd.DataFrame(position[0])[4])
agent5_y = np.array(pd.DataFrame(position[1])[4])
agent5_z = np.array(pd.DataFrame(position[2])[4])

agent6_x = np.array(pd.DataFrame(position[0])[5])
agent6_y = np.array(pd.DataFrame(position[1])[5])
agent6_z = np.array(pd.DataFrame(position[2])[5])

agent1_index = []
agent2_index = []
agent3_index = []
agent4_index = []
agent5_index = []
agent6_index = []
time = []
t = 0
for i in range(len(agent1_x)):
    agent1_index.append("Agent 1")
    agent2_index.append("Agent 2")
    agent3_index.append("Agent 3")
    agent4_index.append("Agent 4")
    agent5_index.append("Agent 5")
    agent6_index.append("Agent 6")
    time.append(t)
    t = t+0.2
    
    
agent1_df = pd.DataFrame(list(zip(time,agent1_index,agent1_x,agent1_y,agent1_z)), columns=['Time','Agent','X','Y','Z'])

agent2_df = pd.DataFrame(list(zip(time,agent2_index,agent2_x,agent2_y,agent2_z)), columns=['Time','Agent','X','Y','Z'])

agent3_df = pd.DataFrame(list(zip(time,agent3_index,agent3_x,agent3_y,agent3_z)), columns=['Time','Agent','X','Y','Z'])

agent4_df = pd.DataFrame(list(zip(time,agent4_index,agent4_x,agent4_y,agent4_z)), columns=['Time','Agent','X','Y','Z'])

agent5_df = pd.DataFrame(list(zip(time,agent5_index,agent5_x,agent5_y,agent5_z)), columns=['Time','Agent','X','Y','Z'])

agent6_df = pd.DataFrame(list(zip(time,agent6_index,agent6_x,agent6_y,agent6_z)), columns=['Time','Agent','X','Y','Z'])

pos_df = agent1_df.append(agent2_df)
pos_df = pos_df.append(agent3_df)
pos_df = pos_df.append(agent4_df)
pos_df = pos_df.append(agent5_df)
pos_df = pos_df.append(agent6_df)

pos_df
# Out:
#     Time    Agent         X         Y         Z
# 0    0.0  Agent 1  2.500000 -1.257225  1.120209
# 1    0.2  Agent 1  2.500061 -1.256991  1.120324
# 2    0.4  Agent 1  2.497817 -1.254576  1.120259
# 3    0.6  Agent 1  2.486198 -1.242841  1.119783
# 4    0.8  Agent 1  2.455597 -1.212949  1.118602
# ..   ...      ...       ...       ...       ...
# 46   9.2  Agent 6  2.536603  0.589416  0.952066
# 47   9.4  Agent 6  2.533856  0.592226  0.954994
# 48   9.6  Agent 6  2.530879  0.594459  0.957581
# 49   9.8  Agent 6  2.527774  0.596200  0.959856
# 50  10.0  Agent 6  2.524621  0.597524  0.961846
#
# [306 rows x 5 columns]

# %%
c = ["#fdb73e", "#00C1CC", '#008CFF', '#8BEB98', '#CF69FF', '#FF7396']

last = len(agent1_x)-1

start1 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 1'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 1'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 1'].Z[0]],
    mode='markers',
    name='Start 1',
    marker=dict(symbol="circle",color=c[0],size=5),
    hovertemplate='Agent 1 start<extra></extra>'
)

end1 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 1'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 1'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 1'].Z[last]],
    mode='markers',
    name='End 1',
    marker=dict(symbol="square",color=c[0],size=5),
    hovertemplate='Agent 1 end<extra></extra>'
)

traj1 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 1'].X,
    y=pos_df[pos_df.Agent=='Agent 1'].Y,
    z=pos_df[pos_df.Agent=='Agent 1'].Z,
    mode='lines',
    name='Trajectory 1',
    line=dict(width=5, color=c[0]),
    hovertemplate='Agent 1 trajectory<extra></extra>'
)

start2 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 2'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 2'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 2'].Z[0]],
    mode='markers',
    name='Start 2',
    marker=dict(symbol="circle",color=c[1],size=5),
    hovertemplate='Agent 2 start<extra></extra>'
)

end2 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 2'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 2'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 2'].Z[last]],
    mode='markers',
    name='End 2',
    marker=dict(symbol="square",color=c[1],size=5),
    hovertemplate='Agent 2 end<extra></extra>'
)

traj2 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 2'].X,
    y=pos_df[pos_df.Agent=='Agent 2'].Y,
    z=pos_df[pos_df.Agent=='Agent 2'].Z,
    mode='lines',
    name='Trajectory 2',
    line=dict(width=5, color=c[1]),
    hovertemplate='Agent 2 end<extra></extra>'
)

start3 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 3'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 3'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 3'].Z[0]],
    mode='markers',
    name='Start 3',
    marker=dict(symbol="circle",color=c[2],size=5),
    hovertemplate='Agent 3 start<extra></extra>'
)

end3 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 3'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 3'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 3'].Z[last]],
    mode='markers',
    name='End 3',
    marker=dict(symbol="square",color=c[2],size=5),
    hovertemplate='Agent 3 end<extra></extra>'
)

traj3 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 3'].X,
    y=pos_df[pos_df.Agent=='Agent 3'].Y,
    z=pos_df[pos_df.Agent=='Agent 3'].Z,
    mode='lines',
    name='Trajectory 3',
    line=dict(width=5, color=c[2]),
    hovertemplate='Agent 3 trajectory<extra></extra>'
)

start4 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 4'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 4'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 4'].Z[0]],
    mode='markers',
    name='Start 4',
    marker=dict(symbol="circle",color=c[3],size=5),
    hovertemplate='Agent 4 start<extra></extra>'
)

end4 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 4'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 4'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 4'].Z[last]],
    mode='markers',
    name='End 4',
    marker=dict(symbol="square",color=c[3],size=5),
    hovertemplate='Agent 4 end<extra></extra>'
)

traj4 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 4'].X,
    y=pos_df[pos_df.Agent=='Agent 4'].Y,
    z=pos_df[pos_df.Agent=='Agent 4'].Z,
    mode='lines',
    name='Trajectory 4',
    line=dict(width=5, color=c[3]),
    hovertemplate='Agent 4 trajectory<extra></extra>'
)

start5 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 5'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 5'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 5'].Z[0]],
    mode='markers',
    name='Start 5',
    marker=dict(symbol="circle",color=c[4],size=5),
    hovertemplate='Agent 5 start<extra></extra>'
)

end5 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 5'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 5'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 5'].Z[last]],
    mode='markers',
    name='End 5',
    marker=dict(symbol="square",color=c[4],size=5),
    hovertemplate='Agent 5 end<extra></extra>'
)

traj5 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 5'].X,
    y=pos_df[pos_df.Agent=='Agent 5'].Y,
    z=pos_df[pos_df.Agent=='Agent 5'].Z,
    mode='lines',
    name='Trajectory 5',
    line=dict(width=5, color=c[4]),
    hovertemplate='Agent 5 trajectory<extra></extra>'
)

start6 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 6'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 6'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 6'].Z[0]],
    mode='markers',
    name='Start 6',
    marker=dict(symbol="circle",color=c[5],size=5),
    hovertemplate='Agent 6 start<extra></extra>'
)

end6 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 6'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 6'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 6'].Z[last]],
    mode='markers',
    name='End 6',
    marker=dict(symbol="square",color=c[5],size=5),
    hovertemplate='Agent 6 end<extra></extra>'
)

traj6 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 6'].X,
    y=pos_df[pos_df.Agent=='Agent 6'].Y,
    z=pos_df[pos_df.Agent=='Agent 6'].Z,
    mode='lines',
    name='Trajectory 6',
    line=dict(width=5, color=c[5]),
    hovertemplate='Agent 6 trajectory<extra></extra>'
)

start = go.Scatter3d(
    x=[10],
    y=[10],
    z=[10],
    mode='markers',
    name='Start',
    marker=dict(symbol="circle",color="#fdb73e",size=5)
)

end = go.Scatter3d(
    x=[10],
    y=[10],
    z=[10],
    mode='markers',
    name='End',
    marker=dict(symbol="square",color="#fdb73e",size=5)
)

traj = go.Scatter3d(
    x=[10],
    y=[10],
    z=[10],
    mode='lines',
    name='Trajectory',
    line=dict(width=5, color="#fdb73e")
)

start_zone = go.Mesh3d(
        x=[-2.5, -2.5, -2.5, -2.5],
        y=[-3, -3, 3, 3],
        z=[1.2, 0.8, 1.2, 0.8],

        i=[0, 0, 0, 1],
        j=[1, 2, 3, 2],
        k=[2, 3, 1, 3],
        opacity=0.1,
        color='#fdb73e',
        flatshading = True,
        hovertemplate='Even Agent<br>Start Zone<extra></extra>'
    )

end_zone = go.Mesh3d(
        x=[2.5, 2.5, 2.5, 2.5],
        y=[-3, -3, 3, 3],
        z=[1.2, 0.8, 1.2, 0.8],

        i=[0, 0, 0, 1],
        j=[1, 2, 3, 2],
        k=[2, 3, 1, 3],
        opacity=0.1,
        color='#fdb73e',
        flatshading = True,
        hovertemplate='Odd Agent<br>Start Zone<extra></extra>'
    )

fig = go.Figure(data=[start1, end1, traj1, 
                      start2, end2, traj2, 
                      start3, end3, traj3, 
                      start4, end4, traj4,
                      start5, end5, traj5,
                      start6, end6, traj6,
                      start, end, traj,
                      start_zone, end_zone])

fig.update_layout({
    'paper_bgcolor': 'rgba(0, 0, 0, 0)',
    'scene_xaxis_backgroundcolor': 'rgba(47, 47, 65, 0.3)',
    'scene_yaxis_backgroundcolor': 'rgba(47, 47, 65, 0.3)',
    'scene_zaxis_backgroundcolor': 'rgba(47, 47, 65, 0.3)',
    'scene_xaxis_linecolor': 'rgba(0, 0, 0, 0)',
    'scene_yaxis_linecolor': 'rgba(0, 0, 0, 0)',
    'scene_zaxis_linecolor': 'rgba(0, 0, 0, 0)',
    'scene_xaxis_gridcolor': 'rgba(0, 0, 0, 0)',
    'scene_yaxis_gridcolor': 'rgba(0, 0, 0, 0)',
    'scene_zaxis_gridcolor': 'rgba(0, 0, 0, 0)',
    
})

fig.update_layout(
    font_color="#fdb73e",
    title={
        'text': "Collision Free Trajecotries with N=6 Agents",
        'y':0.89,
        'x':0.50,
        'font_size': 20}
)

fig.update_layout(
    scene = dict(
        xaxis = dict(range=[-3.5,3.5],),
        yaxis = dict(range=[-3.5,3.5],),
        zaxis = dict(nticks=3, range=[0,2.5],),)
)


fig.update_layout(
    scene_camera = dict(
        up = dict(x=0, y=0, z=1),
        center = dict(x=0, y=0, z=-0.2),
        eye = dict(x=1.2, y=0.5, z=0.5))
)

labels_to_show_in_legend = ["Start","End","Trajectory","Zone"]

for trace in fig['data']: 
    if (not trace['name'] in labels_to_show_in_legend):
        trace['showlegend'] = False

        
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.9,
    xanchor="left",
    x=0.9
))

fig.update_layout(scene_aspectratio=dict(x=1, y=1, z=0.4))

fig.write_html("traj6.html")

fig.show()
# Out:
# <div>                            <div id="117521d5-9d37-4ec0-aee8-816de2e6afc4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("117521d5-9d37-4ec0-aee8-816de2e6afc4")) {                    Plotly.newPlot(                        "117521d5-9d37-4ec0-aee8-816de2e6afc4",                        [{"hovertemplate": "Agent 1 start<extra></extra>", "marker": {"color": "#fdb73e", "size": 5, "symbol": "circle"}, "mode": "markers", "name": "Start 1", "showlegend": false, "type": "scatter3d", "x": [2.5], "y": [-1.2572250507163913], "z": [1.1202091063215405]}, {"hovertemplate": "Agent 1 end<extra></extra>", "marker": {"color": "#fdb73e", "size": 5, "symbol": "square"}, "mode": "markers", "name": "End 1", "showlegend": false, "type": "scatter3d", "x": [-2.51796438
# ...

# %% [markdown]
# # 9 Agents

# %%
position = scipy.io.loadmat('traj9.mat').get("pos_k_i")

agent1_x = np.array(pd.DataFrame(position[0])[0])
agent1_y = np.array(pd.DataFrame(position[1])[0])
agent1_z = np.array(pd.DataFrame(position[2])[0])

agent2_x = np.array(pd.DataFrame(position[0])[1])
agent2_y = np.array(pd.DataFrame(position[1])[1])
agent2_z = np.array(pd.DataFrame(position[2])[1])

agent3_x = np.array(pd.DataFrame(position[0])[2])
agent3_y = np.array(pd.DataFrame(position[1])[2])
agent3_z = np.array(pd.DataFrame(position[2])[2])

agent4_x = np.array(pd.DataFrame(position[0])[3])
agent4_y = np.array(pd.DataFrame(position[1])[3])
agent4_z = np.array(pd.DataFrame(position[2])[3])

agent5_x = np.array(pd.DataFrame(position[0])[4])
agent5_y = np.array(pd.DataFrame(position[1])[4])
agent5_z = np.array(pd.DataFrame(position[2])[4])

agent6_x = np.array(pd.DataFrame(position[0])[5])
agent6_y = np.array(pd.DataFrame(position[1])[5])
agent6_z = np.array(pd.DataFrame(position[2])[5])

agent7_x = np.array(pd.DataFrame(position[0])[6])
agent7_y = np.array(pd.DataFrame(position[1])[6])
agent7_z = np.array(pd.DataFrame(position[2])[6])

agent8_x = np.array(pd.DataFrame(position[0])[7])
agent8_y = np.array(pd.DataFrame(position[1])[7])
agent8_z = np.array(pd.DataFrame(position[2])[7])

agent9_x = np.array(pd.DataFrame(position[0])[8])
agent9_y = np.array(pd.DataFrame(position[1])[8])
agent9_z = np.array(pd.DataFrame(position[2])[8])

agent1_index = []
agent2_index = []
agent3_index = []
agent4_index = []
agent5_index = []
agent6_index = []
agent7_index = []
agent8_index = []
agent9_index = []
time = []
t = 0
for i in range(len(agent1_x)):
    agent1_index.append("Agent 1")
    agent2_index.append("Agent 2")
    agent3_index.append("Agent 3")
    agent4_index.append("Agent 4")
    agent5_index.append("Agent 5")
    agent6_index.append("Agent 6")
    agent7_index.append("Agent 7")
    agent8_index.append("Agent 8")
    agent9_index.append("Agent 9")
    time.append(t)
    t = t+0.2
    
    
agent1_df = pd.DataFrame(list(zip(time,agent1_index,agent1_x,agent1_y,agent1_z)), columns=['Time','Agent','X','Y','Z'])

agent2_df = pd.DataFrame(list(zip(time,agent2_index,agent2_x,agent2_y,agent2_z)), columns=['Time','Agent','X','Y','Z'])

agent3_df = pd.DataFrame(list(zip(time,agent3_index,agent3_x,agent3_y,agent3_z)), columns=['Time','Agent','X','Y','Z'])

agent4_df = pd.DataFrame(list(zip(time,agent4_index,agent4_x,agent4_y,agent4_z)), columns=['Time','Agent','X','Y','Z'])

agent5_df = pd.DataFrame(list(zip(time,agent5_index,agent5_x,agent5_y,agent5_z)), columns=['Time','Agent','X','Y','Z'])

agent6_df = pd.DataFrame(list(zip(time,agent6_index,agent6_x,agent6_y,agent6_z)), columns=['Time','Agent','X','Y','Z'])

agent7_df = pd.DataFrame(list(zip(time,agent7_index,agent7_x,agent7_y,agent7_z)), columns=['Time','Agent','X','Y','Z'])

agent8_df = pd.DataFrame(list(zip(time,agent8_index,agent8_x,agent8_y,agent8_z)), columns=['Time','Agent','X','Y','Z'])

agent9_df = pd.DataFrame(list(zip(time,agent9_index,agent9_x,agent9_y,agent9_z)), columns=['Time','Agent','X','Y','Z'])

pos_df = agent1_df.append(agent2_df)
pos_df = pos_df.append(agent3_df)
pos_df = pos_df.append(agent4_df)
pos_df = pos_df.append(agent5_df)
pos_df = pos_df.append(agent6_df)
pos_df = pos_df.append(agent7_df)
pos_df = pos_df.append(agent8_df)
pos_df = pos_df.append(agent9_df)

pos_df
# Out:
#     Time    Agent         X         Y         Z
# 0    0.0  Agent 1  2.500000 -2.743624  1.195680
# 1    0.2  Agent 1  2.500061 -2.743390  1.195786
# 2    0.4  Agent 1  2.497817 -2.740974  1.195490
# 3    0.6  Agent 1  2.486198 -2.729203  1.193983
# 4    0.8  Agent 1  2.455597 -2.698795  1.190438
# ..   ...      ...       ...       ...       ...
# 46   9.2  Agent 9 -2.528577 -2.166534  1.218228
# 47   9.4  Agent 9 -2.526373 -2.177515  1.213217
# 48   9.6  Agent 9 -2.523953 -2.186303  1.208971
# 49   9.8  Agent 9 -2.521405 -2.193212  1.205399
# 50  10.0  Agent 9 -2.518799 -2.198522  1.202419
#
# [459 rows x 5 columns]

# %%
c = ["#fdb73e", "#00C1CC", '#008CFF', '#8BEB98', '#CF69FF', '#FF7396', "#F9F871", "#FF6222", "#AAA7EF"]

last = len(agent1_x)-1

start1 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 1'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 1'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 1'].Z[0]],
    mode='markers',
    name='Start 1',
    marker=dict(symbol="circle",color=c[0],size=5),
    hovertemplate='Agent 1 start<extra></extra>'
)

end1 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 1'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 1'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 1'].Z[last]],
    mode='markers',
    name='End 1',
    marker=dict(symbol="square",color=c[0],size=5),
    hovertemplate='Agent 1 end<extra></extra>'
)

traj1 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 1'].X,
    y=pos_df[pos_df.Agent=='Agent 1'].Y,
    z=pos_df[pos_df.Agent=='Agent 1'].Z,
    mode='lines',
    name='Trajectory 1',
    line=dict(width=5, color=c[0]),
    hovertemplate='Agent 1 trajectory<extra></extra>'
)

start2 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 2'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 2'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 2'].Z[0]],
    mode='markers',
    name='Start 2',
    marker=dict(symbol="circle",color=c[1],size=5),
    hovertemplate='Agent 2 start<extra></extra>'
)

end2 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 2'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 2'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 2'].Z[last]],
    mode='markers',
    name='End 2',
    marker=dict(symbol="square",color=c[1],size=5),
    hovertemplate='Agent 2 end<extra></extra>'
)

traj2 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 2'].X,
    y=pos_df[pos_df.Agent=='Agent 2'].Y,
    z=pos_df[pos_df.Agent=='Agent 2'].Z,
    mode='lines',
    name='Trajectory 2',
    line=dict(width=5, color=c[1]),
    hovertemplate='Agent 2 end<extra></extra>'
)

start3 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 3'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 3'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 3'].Z[0]],
    mode='markers',
    name='Start 3',
    marker=dict(symbol="circle",color=c[2],size=5),
    hovertemplate='Agent 3 start<extra></extra>'
)

end3 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 3'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 3'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 3'].Z[last]],
    mode='markers',
    name='End 3',
    marker=dict(symbol="square",color=c[2],size=5),
    hovertemplate='Agent 3 end<extra></extra>'
)

traj3 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 3'].X,
    y=pos_df[pos_df.Agent=='Agent 3'].Y,
    z=pos_df[pos_df.Agent=='Agent 3'].Z,
    mode='lines',
    name='Trajectory 3',
    line=dict(width=5, color=c[2]),
    hovertemplate='Agent 3 trajectory<extra></extra>'
)

start4 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 4'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 4'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 4'].Z[0]],
    mode='markers',
    name='Start 4',
    marker=dict(symbol="circle",color=c[3],size=5),
    hovertemplate='Agent 4 start<extra></extra>'
)

end4 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 4'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 4'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 4'].Z[last]],
    mode='markers',
    name='End 4',
    marker=dict(symbol="square",color=c[3],size=5),
    hovertemplate='Agent 4 end<extra></extra>'
)

traj4 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 4'].X,
    y=pos_df[pos_df.Agent=='Agent 4'].Y,
    z=pos_df[pos_df.Agent=='Agent 4'].Z,
    mode='lines',
    name='Trajectory 4',
    line=dict(width=5, color=c[3]),
    hovertemplate='Agent 4 trajectory<extra></extra>'
)

start5 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 5'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 5'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 5'].Z[0]],
    mode='markers',
    name='Start 5',
    marker=dict(symbol="circle",color=c[4],size=5),
    hovertemplate='Agent 5 start<extra></extra>'
)

end5 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 5'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 5'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 5'].Z[last]],
    mode='markers',
    name='End 5',
    marker=dict(symbol="square",color=c[4],size=5),
    hovertemplate='Agent 5 end<extra></extra>'
)

traj5 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 5'].X,
    y=pos_df[pos_df.Agent=='Agent 5'].Y,
    z=pos_df[pos_df.Agent=='Agent 5'].Z,
    mode='lines',
    name='Trajectory 5',
    line=dict(width=5, color=c[4]),
    hovertemplate='Agent 5 trajectory<extra></extra>'
)

start6 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 6'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 6'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 6'].Z[0]],
    mode='markers',
    name='Start 6',
    marker=dict(symbol="circle",color=c[5],size=5),
    hovertemplate='Agent 6 start<extra></extra>'
)

end6 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 6'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 6'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 6'].Z[last]],
    mode='markers',
    name='End 6',
    marker=dict(symbol="square",color=c[5],size=5),
    hovertemplate='Agent 6 end<extra></extra>'
)

traj6 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 6'].X,
    y=pos_df[pos_df.Agent=='Agent 6'].Y,
    z=pos_df[pos_df.Agent=='Agent 6'].Z,
    mode='lines',
    name='Trajectory 6',
    line=dict(width=5, color=c[5]),
    hovertemplate='Agent 6 trajectory<extra></extra>'
)

start7 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 7'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 7'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 7'].Z[0]],
    mode='markers',
    name='Start 7',
    marker=dict(symbol="circle",color=c[6],size=5),
    hovertemplate='Agent 7 start<extra></extra>'
)

end7 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 7'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 7'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 7'].Z[last]],
    mode='markers',
    name='End 6',
    marker=dict(symbol="square",color=c[6],size=5),
    hovertemplate='Agent 7 end<extra></extra>'
)

traj7 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 7'].X,
    y=pos_df[pos_df.Agent=='Agent 7'].Y,
    z=pos_df[pos_df.Agent=='Agent 7'].Z,
    mode='lines',
    name='Trajectory 7',
    line=dict(width=5, color=c[6]),
    hovertemplate='Agent 7 trajectory<extra></extra>'
)

start8 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 8'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 8'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 8'].Z[0]],
    mode='markers',
    name='Start 6',
    marker=dict(symbol="circle",color=c[7],size=5),
    hovertemplate='Agent 8 start<extra></extra>'
)

end8 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 8'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 8'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 8'].Z[last]],
    mode='markers',
    name='End 8',
    marker=dict(symbol="square",color=c[7],size=5),
    hovertemplate='Agent 8 end<extra></extra>'
)

traj8 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 8'].X,
    y=pos_df[pos_df.Agent=='Agent 8'].Y,
    z=pos_df[pos_df.Agent=='Agent 8'].Z,
    mode='lines',
    name='Trajectory 8',
    line=dict(width=5, color=c[7]),
    hovertemplate='Agent 8 trajectory<extra></extra>'
)

start9 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 9'].X[0]],
    y=[pos_df[pos_df.Agent=='Agent 9'].Y[0]],
    z=[pos_df[pos_df.Agent=='Agent 9'].Z[0]],
    mode='markers',
    name='Start 9',
    marker=dict(symbol="circle",color=c[8],size=5),
    hovertemplate='Agent 9 start<extra></extra>'
)

end9 = go.Scatter3d(
    x=[pos_df[pos_df.Agent=='Agent 9'].X[last]],
    y=[pos_df[pos_df.Agent=='Agent 9'].Y[last]],
    z=[pos_df[pos_df.Agent=='Agent 9'].Z[last]],
    mode='markers',
    name='End 9',
    marker=dict(symbol="square",color=c[8],size=5),
    hovertemplate='Agent 9 end<extra></extra>'
)

traj9 = go.Scatter3d(
    x=pos_df[pos_df.Agent=='Agent 9'].X,
    y=pos_df[pos_df.Agent=='Agent 9'].Y,
    z=pos_df[pos_df.Agent=='Agent 9'].Z,
    mode='lines',
    name='Trajectory 9',
    line=dict(width=5, color=c[8]),
    hovertemplate='Agent 9 trajectory<extra></extra>'
)

start = go.Scatter3d(
    x=[10],
    y=[10],
    z=[10],
    mode='markers',
    name='Start',
    marker=dict(symbol="circle",color="#fdb73e",size=5)
)

end = go.Scatter3d(
    x=[10],
    y=[10],
    z=[10],
    mode='markers',
    name='End',
    marker=dict(symbol="square",color="#fdb73e",size=5)
)

traj = go.Scatter3d(
    x=[10],
    y=[10],
    z=[10],
    mode='lines',
    name='Trajectory',
    line=dict(width=5, color="#fdb73e")
)

start_zone = go.Mesh3d(
        x=[-2.5, -2.5, -2.5, -2.5],
        y=[-3, -3, 3, 3],
        z=[1.2, 0.8, 1.2, 0.8],

        i=[0, 0, 0, 1],
        j=[1, 2, 3, 2],
        k=[2, 3, 1, 3],
        opacity=0.1,
        color='#fdb73e',
        flatshading = True,
        hovertemplate='Even Agent<br>Start Zone<extra></extra>'
    )

end_zone = go.Mesh3d(
        x=[2.5, 2.5, 2.5, 2.5],
        y=[-3, -3, 3, 3],
        z=[1.2, 0.8, 1.2, 0.8],

        i=[0, 0, 0, 1],
        j=[1, 2, 3, 2],
        k=[2, 3, 1, 3],
        opacity=0.1,
        color='#fdb73e',
        flatshading = True,
        hovertemplate='Odd Agent<br>Start Zone<extra></extra>'
    )

fig = go.Figure(data=[start1, end1, traj1, 
                      start2, end2, traj2, 
                      start3, end3, traj3, 
                      start4, end4, traj4,
                      start5, end5, traj5,
                      start6, end6, traj6, 
                      start7, end7, traj7,
                      start8, end8, traj8,
                      start9, end9, traj9,
                      start, end, traj,
                      start_zone, end_zone])

fig.update_layout({
    'paper_bgcolor': 'rgba(0, 0, 0, 0)',
    'scene_xaxis_backgroundcolor': 'rgba(47, 47, 65, 0.3)',
    'scene_yaxis_backgroundcolor': 'rgba(47, 47, 65, 0.3)',
    'scene_zaxis_backgroundcolor': 'rgba(47, 47, 65, 0.3)',
    'scene_xaxis_linecolor': 'rgba(0, 0, 0, 0)',
    'scene_yaxis_linecolor': 'rgba(0, 0, 0, 0)',
    'scene_zaxis_linecolor': 'rgba(0, 0, 0, 0)',
    'scene_xaxis_gridcolor': 'rgba(0, 0, 0, 0)',
    'scene_yaxis_gridcolor': 'rgba(0, 0, 0, 0)',
    'scene_zaxis_gridcolor': 'rgba(0, 0, 0, 0)',
    
})

fig.update_layout(
    font_color="#fdb73e",
    title={
        'text': "Collision Free Trajecotries with N=9 Agents",
        'y':0.89,
        'x':0.50,
        'font_size': 20}
)

fig.update_layout(
    scene = dict(
        xaxis = dict(range=[-3.5,3.5],),
        yaxis = dict(range=[-3.5,3.5],),
        zaxis = dict(nticks=3, range=[0,2.5],),)
)


fig.update_layout(
    scene_camera = dict(
        up = dict(x=0, y=0, z=1),
        center = dict(x=0, y=0, z=-0.2),
        eye = dict(x=1.2, y=0.5, z=0.5))
)

labels_to_show_in_legend = ["Start","End","Trajectory","Zone"]

for trace in fig['data']: 
    if (not trace['name'] in labels_to_show_in_legend):
        trace['showlegend'] = False

        
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.9,
    xanchor="left",
    x=0.9
))

fig.update_layout(scene_aspectratio=dict(x=1, y=1, z=0.4))

fig.write_html("traj9.html")

fig.show()
# Out:
# <div>                            <div id="f2e006e3-37b2-4a32-922c-69a6355a7c22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2e006e3-37b2-4a32-922c-69a6355a7c22")) {                    Plotly.newPlot(                        "f2e006e3-37b2-4a32-922c-69a6355a7c22",                        [{"hovertemplate": "Agent 1 start<extra></extra>", "marker": {"color": "#fdb73e", "size": 5, "symbol": "circle"}, "mode": "markers", "name": "Start 1", "showlegend": false, "type": "scatter3d", "x": [2.5], "y": [-2.743624309887581], "z": [1.1956803479168645]}, {"hovertemplate": "Agent 1 end<extra></extra>", "marker": {"color": "#fdb73e", "size": 5, "symbol": "square"}, "mode": "markers", "name": "End 1", "showlegend": false, "type": "scatter3d", "x": [-2.488686164
# ...
